# %% [markdown]
# <a href="https://colab.research.google.com/github/SALIHAIREM1/pizza_order_system_basic/blob/main/salihairemakan_aihub_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import datetime 

print("Merhaba, Pizza salonumuza hoşgeldiniz...")
print("Pizza çeşitlerimiz ve içeriği aşağıdaki gibidir; \n 1: Klasik- Mozarella, sucuk, sosis. \n 2: Margarita - Domates, mozzarella, fesleğen. \n 3: TürkPizza - Pastırma, sucuk, kaşar. \n 4: Sade Pizza - Kaşar peyniri, mozzarella peyniri, kırmızı biber, domates.")
print("Açılışa özel tüm pizzalarımız 75,00 TL olup her sosumuz 15,00 TL'dir. Şimdiden Afiyet Olsun...")
taban=input("Lütfen Bir Pizza Tabanı Seçiniz: \n 1: Klasik \n 2: Margarita \n 3: TürkPizza \n 4: Sade Pizza \n")

#Kredi kartı bilgileri girişi için tanımlanan fonksiyon
def kredi_kartı():
  for i in range(1):
      isim = input("Lütfen kredi kartı üzerinde yazan isiminizi giriniz:")
      tc_no = input("Lütfen TC kimlik numaranızı giriniz:")
      kart_no =input("Lütfen kredi kartı numaranızı giriniz:")
      sifre = input("Şifreniz:")
  print(isim, tc_no, kart_no, sifre, "\n Ödemeniz başarıyla alınmıştır efendim, bizi tercih ettiğiniz için teşekkür ederiz.")


#Taban seçimi için;
if (taban == "1"):
  #1. tabana ait sos seçimi için;
  print("Klasik pizzanıza hangi sosu eklemek isterseniz?")
  sos=input("Lütfen Bir Sos Seçiniz: \n 11: Zeytin \n 12: Mantarlar \n 13: Keçi Peyniri \n 14: Et \n 15: Soğan \n 16: Mısır \n")
  if (sos == "11"):
    print("Zeytinli Klasik Pizzanızın siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "12"):
    print("Mantarlı Klasik Pizzanızın siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "13"):
    print("Keçi Peynirli Klasik Pizzanızın siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "14"):
    print("Etli Klasik Pizzanızın siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "15"):
    print("Soğanlı Klasik Pizzanızın siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "16"):
    print("Mısırlı Klasik Pizzanızın siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  else:
    print("Sos seçimi yapılmadı, Ödenecek tutar: 75,00 TL")
    kredi_kartı()


elif (taban == "2"):
  #2. tabana ait sos seçimi için;
  print("Margarita pizzanıza hangi sosu eklemek isterseniz?")
  sos=input("Lütfen Bir Sos Seçiniz: \n 11: Zeytin \n 12: Mantarlar \n 13: Keçi Peyniri \n 14: Et \n 15: Soğan \n 16: Mısır \n")
  if (sos == "11"):
    print("Zeytinli Margarita Pizzanızın siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "12"):
    print("Mantarlı Margarita Pizzanızın siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "13"):
    print("Keçi Peynirli Margarita Pizzanızın siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "14"):
    print("Etli Margarita Pizzanızın siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "15"):
    print("Soğanlı Margarita Pizzanızın siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "16"):
    print("Mısırlı Margarita Pizzanızın siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  else:
    print("Sos seçimi yapılmadı, Ödenecek tutar: 75,00 TL")
    kredi_kartı()
  
elif (taban == "3"):
  #3. tabana ait sos seçimi için;
  print("TürkPizza'nıza hangi sosu eklemek isterseniz?")
  sos=input("Lütfen Bir Sos Seçiniz: \n 11: Zeytin \n 12: Mantarlar \n 13: Keçi Peyniri \n 14: Et \n 15: Soğan \n 16: Mısır \n")
  if (sos == "11"):
    print("Zeytinli TürkPizza siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "12"):
    print("Mantarlı TürkPizza siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "13"):
    print("Keçi Peynirli TürkPizza siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "14"):
    print("Etli TürkPizza siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "15"):
    print("Soğanlı TürkPizza siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "16"):
    print("Mısırlı TürkPizza siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  else:
    print("Sos seçimi yapılmadı, Ödenecek tutar: 75,00 TL")
    kredi_kartı()

elif (taban == "4"):
  #4. tabana ait sos seçimi için;
  print("Sade pizzanıza hangi sosu eklemek isterseniz?")
  sos=input("Lütfen Bir Sos Seçiniz: \n 11: Zeytin \n 12: Mantarlar \n 13: Keçi Peyniri \n 14: Et \n 15: Soğan \n 16: Mısır \n")
  if (sos == "11"):
    print("Zeytinli Sade pizza siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "12"):
    print("Mantarlı Sade pizza siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "13"):
    print("Keçi Peynirli Sade pizza siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "14"):
    print("Etli Sade pizza siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "15"):
    print("Soğanlı Sade pizza siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  elif (sos == "16"):
    print("Mısırlı Sade pizza siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL")
    kredi_kartı()
  else:
    print("Sos seçimi yapılmadı, Ödenecek tutar: 75,00 TL")
    kredi_kartı()

else:
  print("Seçim yapılmadı, lütfen teknik ekipten yardım isteyiniz.")
# Out:
# Merhaba, Pizza salonumuza hoşgeldiniz...
# Pizza çeşitlerimiz ve içeriği aşağıdaki gibidir;
#  1: Klasik- Mozarella, sucuk, sosis.
#  2: Margarita - Domates, mozzarella, fesleğen.
#  3: TürkPizza - Pastırma, sucuk, kaşar.
#  4: Sade Pizza - Kaşar peyniri, mozzarella peyniri, kırmızı biber, domates.
# Açılışa özel tüm pizzalarımız 75,00 TL olup her sosumuz 15,00 TL'dir. Şimdiden Afiyet Olsun...
# Lütfen Bir Pizza Tabanı Seçiniz:
#  1: Klasik
#  2: Margarita
#  3: TürkPizza
#  4: Sade Pizza
# 2
# Margarita pizzanıza hangi sosu eklemek isterseniz?
# Lütfen Bir Sos Seçiniz:
#  11: Zeytin
#  12: Mantarlar
#  13: Keçi Peyniri
#  14: Et
#  15: Soğan
#  16: Mısır
# 16
# Mısırlı Margarita Pizzanızın siparişi alınmıştır efendim. Ödenecek tutar: 80,00 TL
# Lütfen kredi kartı üzerinde yazan isiminizi giriniz:sdfghjkl
# Lütfen TC kimlik numaranızı giriniz:5641ü
# Lütfen kredi kartı numaranızı giriniz:8520634
# Şifreniz:456
# sdfghjkl 5641ü 8520634 456
# ...
